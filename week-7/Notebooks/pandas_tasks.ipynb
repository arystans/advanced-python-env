# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Magua", "Aru", "Dima", "MR.DIr", "Nura"],
    "Age": [18, 60, 23, 40, 2],
    "Score": [76, 88, 91, 100, 268]
})
df.to_csv("students.csv", index=False)
print(df)
# Out:
# Exception ignored in PyObject_HasAttr(); consider using PyObject_HasAttrWithError(), PyObject_GetOptionalAttr() or PyObject_GetAttr():
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 491, in _call_with_frames_removed
# AttributeError: partially initialized module 'pandas' from 'C:\Users\24680\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\__init__.py' has no attribute '_pandas_datetime_CAPI' (most likely due to a circular import)
# Exception ignored in PyObject_HasAttr(); consider using PyObject_HasAttrWithError(), PyObject_GetOptionalAttr() or PyObject_GetAttr():
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 491, in _call_with_frames_removed
# AttributeError: partially initialized module 'pandas' from 'C:\Users\24680\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\__init__.py' has no attribute '_pandas_parser_CAPI' (most likely due to a circular import)
# ...

# %%
print(df.head(3))
# Out:
#     Name  Age  Score
# 0  Magua   18     76
# 1    Aru   60     88
# 2   Dima   23     91

# %%
print(df.describe())
# Out:
#              Age       Score
# count   5.000000    5.000000
# mean   28.600000  124.600000
# std    22.176564   80.621337
# min     2.000000   76.000000
# 25%    18.000000   88.000000
# 50%    23.000000   91.000000
# 75%    40.000000  100.000000
# max    60.000000  268.000000

# %%
print(df["Score"].mean())
# Out:
# 124.6

# %%
print(df[df["Score"] > 80])
# Out:
#      Name  Age  Score
# 1     Aru   60     88
# 2    Dima   23     91
# 3  MR.DIr   40    100
# 4    Nura    2    268

# %%
print(df[df["Age"] > 2])
# Out:
#      Name  Age  Score
# 0   Magua   18     76
# 1     Aru   60     88
# 2    Dima   23     91
# 3  MR.DIr   40    100
